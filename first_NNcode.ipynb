# %% [markdown]
# <a href="https://colab.research.google.com/github/sonudk/Source-Code-from-Tutorials/blob/master/first_NNcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn
import keras
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense

# %%
np.random.seed(1)
model=Sequential()
model.add(Dense(10,input_dim=1,activation='relu'))
model.add(Dense(30,activation='relu'))
model.add(Dense(23,activation='relu'))

model.add(Dense(1,activation='linear'))
model.compile(loss='mse',optimizer='adam')

# %%
vals=30
X=np.array([[i] for i in range(vals)])
Y=np.array([j+5 for j in X])+ np.random.uniform(0,0.5,(vals,1))

# %%
model.fit(X,Y,epochs=1000)
plt.scatter(X,Y)
Y_pre=model.predict(X)
plt.plot(X,Y_pre)
# Out:
# Epoch 1/1000
# 30/30 [==============================] - 0s 9ms/step - loss: 384.1153
# Epoch 2/1000
# 30/30 [==============================] - 0s 73us/step - loss: 377.9800
# Epoch 3/1000
# 30/30 [==============================] - 0s 66us/step - loss: 370.9418
# Epoch 4/1000
# 30/30 [==============================] - 0s 48us/step - loss: 363.5318
# Epoch 5/1000
# 30/30 [==============================] - 0s 42us/step - loss: 355.9394
# Epoch 6/1000
# 30/30 [==============================] - 0s 42us/step - loss: 348.2540
# Epoch 7/1000
# 30/30 [==============================] - 0s 45us/step - loss: 340.5262
# Epoch 8/1000
# 30/30 [==============================] - 0s 44us/step - loss: 332.6743
# Epoch 9/1000
# 30/30 [==============================] - 0s 59us/step - loss: 325.2327
# Epoch 10/1000
# 30/30 [==============================] - 0s 54us/step - loss: 317.7857
# Epoch 11/1000
# 30/30 [==============================] - 0s 88us/step - loss: 310.3455
# Epoch 12/1000
# ...
